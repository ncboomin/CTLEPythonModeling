# %%
import sympy 
import math 
from sympy import*



# %run TransferResponseCode.ipynb
# %run OutputPlot.ipynb
# %run JustSampling.ipynb



###Define input Signal
f=40
inputSig=cos(2*pi*t) + cos(2*pi*f*t)
inputResponse=inputToLaplace(inputSig)


##Def Equalizer Response
hOfs=transferResponse(5, 5, 5, 5, 5)

###Full System Response
sigOut = hOfs*inputResponse
print(sigOut)


#Convert the output back to time Domain
outputSig = nsimplify(sigOut)
finalSig=inverseLaplace(outputSig)
print(simplify(outputSig))

##Evaluate the output in time domain
plotGraph(finalSig)
plotSampled(finalSig, f)
#Plot the graph for the function
# Out:
# (600.0*s + 24.0)/(25*s + 13.5)
# 2*s*(600.0*s + 24.0)*(s**2 + 3202*pi**2)/((25*s + 13.5)*(s**2 + 4*pi**2)*(s**2 + 6400*pi**2))
# 48*((729 + 16000000*pi**2)*(531441 + 11671290000*pi**2 + 160000000000*pi**4)*(-1250*pi*sin(2*pi*t) + 27*cos(2*pi*t) + 5000*pi**2*cos(2*pi*t))*exp(27*t/50) + (729 + 10000*pi**2)*(531441 + 11671290000*pi**2 + 160000000000*pi**4)*(-50000*pi*sin(80*pi*t) + 27*cos(80*pi*t) + 8000000*pi**2*cos(80*pi*t))*exp(27*t/50) + 675*(729 + 10000*pi**2)*(729 + 8005000*pi**2)*(729 + 16000000*pi**2))*exp(-27*t/50)*Heaviside(t)/((729 + 10000*pi**2)*(729 + 16000000*pi**2)*(531441 + 11671290000*pi**2 + 160000000000*pi**4))
# 96*s*(25*s + 1)*(s**2 + 3202*pi**2)/((50*s + 27)*(s**2 + 4*pi**2)*(s**2 + 6400*pi**2))
# <img src="data:image/png;base64,..." width="640">
# 24.000000000000004
# 4.035752923334482
# 32.176393728488875
# 28.819686396747034
# 4.902000048786483
# 46.01475719525101
# 0.22889835572998737
# 32.24176276808519
# 22.676975151716384
# 3.5027592303295445
# ...
